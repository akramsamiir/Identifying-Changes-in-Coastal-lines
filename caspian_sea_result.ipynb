# %%
import cv2
from skimage.io import imread
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pickle
import os
import glob
# from skimage.io import imread, imsave
# from keras.models import model_from_json
# from tensorflow.keras.models import load_model
# from model import load_model
from codes import model

# %%
roi_path = r"C:\Users\Muhammed\Documents\Graduation Project\caspian sea dataset\roi masks"
images_path = r"C:\Users\Muhammed\Documents\Graduation Project\caspian sea dataset\gt"

# %%
roi_images = ["165034-mask.tif", "166032-mask.tif", "166034-mask.tif"]
images = ["165034-2013-gt.tif", "166032-2013-gt.tif", "166034-2013-gt.tif"]

# %%
def display_image(image_name, image_path ):
    img = mpimg.imread(f"{image_path}\{image_name}")
    plt.imshow(img, cmap="Greys")

# %% [markdown]
# DeepLab<br/>

# %%
deeplab = model.load_model('deeplab.h5', compile=False)

# %%
model.all_metrics(deeplab)
# Out:
# Mean Accuracy:    0.8044
#                 Mean Sensitivity: 0.7075
#                 Mean Precision:   0.8761
#                 Mean F1-Score:    0.7761
#                 Mean IoU:         0.6472

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(deeplab, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(deeplab, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(deeplab, images[2])

# %% [markdown]
# Fcdensenet<br/>
# Accept RGB Image

# %%
fcdensennet = model.load_model("fcdensennet.h5")

# %%
model.all_metrics(fcdensennet)
# Out:
# Mean Accuracy:    0.9242
#                 Mean Sensitivity: 0.8567
#                 Mean Precision:   0.9899
#                 Mean F1-Score:    0.9144
#                 Mean IoU:         0.8492

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(fcdensennet, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(fcdensennet, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(fcdensennet, images[2])

# %% [markdown]
# Model1_Scenario1<br/>

# %%
Model1_Scenario1 = model.load_model("Model1_Scenario1.h5", compile=False)

# %%
model.all_metrics(Model1_Scenario1)
# Out:
# Mean Accuracy:    0.9462
#                 Mean Sensitivity: 0.9094
#                 Mean Precision:   0.9862
#                 Mean F1-Score:    0.9437
#                 Mean IoU:         0.8992

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(Model1_Scenario1, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(Model1_Scenario1, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(Model1_Scenario1, images[2])

# %% [markdown]
# Model1_Scenario2<br/>

# %%
Model1_Scenario2 = model.load_model("Model1_Scenario2.h5", compile=False)

# %%
model.all_metrics(Model1_Scenario2)
# Out:
# Mean Accuracy:    0.9879
#                 Mean Sensitivity: 0.9780
#                 Mean Precision:   0.9973
#                 Mean F1-Score:    0.9875
#                 Mean IoU:         0.9754

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(Model1_Scenario2, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(Model1_Scenario2, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(Model1_Scenario2, images[2])

# %% [markdown]
# Model2_Scenario1

# %%
Model2_Scenario1 = model.load_model("Model2_Scenario1.h5", compile= False)

# %%
model.all_metrics(Model2_Scenario1)
# Out:
# Mean Accuracy:    0.9513
#                     Mean Sensitivity: 0.9253
#                     Mean Precision:   0.9276
#                     Mean F1-Score:    0.9314
#                     Mean IoU:         0.9129

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(Model2_Scenario1, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(Model2_Scenario1, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(Model1_Scenario1, images[0])

# %% [markdown]
# Model2_Scenario2

# %%
Model2_Scenario2 = model.load_model("Model2_Scenario2.h5", compile= False)

# %%
model.all_metrics(Model2_Scenario2)
# Out:
# Mean Accuracy:    0.9543
#                 Mean Sensitivity: 0.9505
#                 Mean Precision:   0.9582
#                 Mean F1-Score:    0.9443
#                 Mean IoU:         0.9487

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(Model2_Scenario2, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(Model2_Scenario2, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(Model2_Scenario2, images[2])

# %% [markdown]
# Model3_Scenario1<br/>

# %%
Model3_Scenario1 = model.load_model("Model3_Scenario1.h5", compile= False)

# %%
model.all_metrics(Model3_Scenario1)
# Out:
# Mean Accuracy: 0.9134
#                 Mean Sensitivity: 0.9071
#                 Mean Precision: 0.9085
#                 Mean F1-Score: 0.8936
#                 Mean IoU: 0.933

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(Model3_Scenario1, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(Model3_Scenario1, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(Model3_Scenario1, images[2])

# %% [markdown]
# Model3_Scenario2<br/>

# %%
Model3_Scenario2 = model.load_model("Model3_Scenario2.h5", compile= False)

# %%
model.all_metrics(Model3_Scenario2)
# Out:
# Mean Accuracy:    0.9194
#                 Mean Sensitivity: 0.9182
#                 Mean Precision:   0.9010
#                 Mean F1-Score:    0.9081
#                 Mean IoU:         0.9109

# %%
display_image(roi_images[0], roi_path)

# %%
model.predict(Model3_Scenario2, images[0])

# %%
display_image(roi_images[1], roi_path)

# %%
model.predict(Model3_Scenario2, images[1])

# %%
display_image(roi_images[2], roi_path)

# %%
model.predict(Model3_Scenario2, images[2])
